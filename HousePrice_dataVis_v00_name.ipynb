# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import platform
# sns.set()

from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:
    print("It's unknown system. Hangul fonts are not supported!")
    
plt.rcParams["figure.figsize"] = [12,6]

# %matplotlib notebook

# %%
df = pd.read_csv('data/train.csv', sep=',', encoding='UTF-8')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
df1 = df[df.columns[:29]]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# 11      12          60       RL         85.0    11924   Pave   NaN      IR1
# 12      13          20       RL          NaN    12968   Pave   NaN      IR2
# 13      14          20       RL         91.0    10652   Pave   NaN      IR1
# 14      15          20       RL          NaN    10920   Pave   NaN      IR1
# 15      16          45       RM         51.0     6120   Pave   NaN      Reg
# 16      17          20       RL          NaN    11241   Pave   NaN      IR1
# 17      18          90       RL         72.0    10791   Pave   NaN      Reg
# 18      19          20       RL         66.0    13695   Pave   NaN      Reg
# 19      20          20       RL         70.0     7560   Pave   NaN      Reg
# 20      21          60       RL        101.0    14215   Pave   NaN      IR1
# 21      22          45       RM         57.0     7449   Pave  Grvl      Reg
# 22      23          20       RL         75.0     9742   Pave   NaN      Reg
# 23      24         120       RM         44.0     4224   Pave   NaN      Reg
# 24      25          20       RL          NaN     8246   Pave   NaN      IR1
# 25      26          20       RL        110.0    14230   Pave   NaN      Reg
# 26      27          20       RL         60.0     7200   Pave   NaN      Reg
# 27      28          20       RL         98.0    11478   Pave   NaN      Reg
# 28      29          20       RL         47.0    16321   Pave   NaN      IR1
# 29      30          30       RM         60.0     6324   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1430  1431          60       RL         60.0    21930   Pave   NaN      IR3
# 1431  1432         120       RL          NaN     4928   Pave   NaN      IR1
# 1432  1433          30       RL         60.0    10800   Pave  Grvl      Reg
# 1433  1434          60       RL         93.0    10261   Pave   NaN      IR1
# 1434  1435          20       RL         80.0    17400   Pave   NaN      Reg
# 1435  1436          20       RL         80.0     8400   Pave   NaN      Reg
# 1436  1437          20       RL         60.0     9000   Pave   NaN      Reg
# 1437  1438          20       RL         96.0    12444   Pave   NaN      Reg
# 1438  1439          20       RM         90.0     7407   Pave   NaN      Reg
# 1439  1440          60       RL         80.0    11584   Pave   NaN      Reg
# 1440  1441          70       RL         79.0    11526   Pave   NaN      IR1
# 1441  1442         120       RM          NaN     4426   Pave   NaN      Reg
# 1442  1443          60       FV         85.0    11003   Pave   NaN      Reg
# 1443  1444          30       RL          NaN     8854   Pave   NaN      Reg
# 1444  1445          20       RL         63.0     8500   Pave   NaN      Reg
# 1445  1446          85       RL         70.0     8400   Pave   NaN      Reg
# 1446  1447          20       RL          NaN    26142   Pave   NaN      IR1
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg
# 1448  1449          50       RL         70.0    11767   Pave   NaN      Reg
# 1449  1450         180       RM         21.0     1533   Pave   NaN      Reg
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities    ...     YearBuilt YearRemodAdd RoofStyle  \
# 0            Lvl    AllPub    ...          2003         2003     Gable
# 1            Lvl    AllPub    ...          1976         1976     Gable
# 2            Lvl    AllPub    ...          2001         2002     Gable
# 3            Lvl    AllPub    ...          1915         1970     Gable
# 4            Lvl    AllPub    ...          2000         2000     Gable
# 5            Lvl    AllPub    ...          1993         1995     Gable
# 6            Lvl    AllPub    ...          2004         2005     Gable
# 7            Lvl    AllPub    ...          1973         1973     Gable
# 8            Lvl    AllPub    ...          1931         1950     Gable
# 9            Lvl    AllPub    ...          1939         1950     Gable
# 10           Lvl    AllPub    ...          1965         1965       Hip
# 11           Lvl    AllPub    ...          2005         2006       Hip
# 12           Lvl    AllPub    ...          1962         1962       Hip
# 13           Lvl    AllPub    ...          2006         2007     Gable
# 14           Lvl    AllPub    ...          1960         1960       Hip
# 15           Lvl    AllPub    ...          1929         2001     Gable
# 16           Lvl    AllPub    ...          1970         1970     Gable
# 17           Lvl    AllPub    ...          1967         1967     Gable
# 18           Lvl    AllPub    ...          2004         2004     Gable
# 19           Lvl    AllPub    ...          1958         1965       Hip
# 20           Lvl    AllPub    ...          2005         2006     Gable
# 21           Bnk    AllPub    ...          1930         1950     Gable
# 22           Lvl    AllPub    ...          2002         2002       Hip
# 23           Lvl    AllPub    ...          1976         1976     Gable
# 24           Lvl    AllPub    ...          1968         2001     Gable
# 25           Lvl    AllPub    ...          2007         2007     Gable
# 26           Lvl    AllPub    ...          1951         2000     Gable
# 27           Lvl    AllPub    ...          2007         2008     Gable
# 28           Lvl    AllPub    ...          1957         1997     Gable
# 29           Lvl    AllPub    ...          1927         1950     Gable
# ...          ...       ...    ...           ...          ...       ...
# 1430         Lvl    AllPub    ...          2005         2005     Gable
# 1431         Lvl    AllPub    ...          1976         1976     Gable
# 1432         Lvl    AllPub    ...          1927         2007     Gable
# 1433         Lvl    AllPub    ...          2000         2000     Gable
# 1434         Low    AllPub    ...          1977         1977     Gable
# 1435         Lvl    AllPub    ...          1962         2005     Gable
# 1436         Lvl    AllPub    ...          1971         1971     Gable
# 1437         Lvl    AllPub    ...          2008         2008       Hip
# 1438         Lvl    AllPub    ...          1957         1996     Gable
# 1439         Lvl    AllPub    ...          1979         1979       Hip
# 1440         Bnk    AllPub    ...          1922         1994     Gable
# 1441         Lvl    AllPub    ...          2004         2004     Gable
# 1442         Lvl    AllPub    ...          2008         2008     Gable
# 1443         Lvl    AllPub    ...          1916         1950     Gable
# 1444         Lvl    AllPub    ...          2004         2004     Gable
# 1445         Lvl    AllPub    ...          1966         1966     Gable
# 1446         Lvl    AllPub    ...          1962         1962     Gable
# 1447         Lvl    AllPub    ...          1995         1996     Gable
# 1448         Lvl    AllPub    ...          1910         2000     Gable
# 1449         Lvl    AllPub    ...          1970         1970     Gable
# 1450         Lvl    AllPub    ...          1974         1974     Gable
# 1451         Lvl    AllPub    ...          2008         2009     Gable
# 1452         Lvl    AllPub    ...          2005         2005     Gable
# 1453         Lvl    AllPub    ...          2006         2006     Gable
# 1454         Lvl    AllPub    ...          2004         2005     Gable
# 1455         Lvl    AllPub    ...          1999         2000     Gable
# 1456         Lvl    AllPub    ...          1978         1988     Gable
# 1457         Lvl    AllPub    ...          1941         2006     Gable
# 1458         Lvl    AllPub    ...          1950         1996       Hip
# 1459         Lvl    AllPub    ...          1965         1965     Gable
#
#      RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea  ExterQual  \
# 0     CompShg     VinylSd     VinylSd    BrkFace       196.0         Gd
# 1     CompShg     MetalSd     MetalSd       None         0.0         TA
# 2     CompShg     VinylSd     VinylSd    BrkFace       162.0         Gd
# 3     CompShg     Wd Sdng     Wd Shng       None         0.0         TA
# 4     CompShg     VinylSd     VinylSd    BrkFace       350.0         Gd
# 5     CompShg     VinylSd     VinylSd       None         0.0         TA
# 6     CompShg     VinylSd     VinylSd      Stone       186.0         Gd
# 7     CompShg     HdBoard     HdBoard      Stone       240.0         TA
# 8     CompShg     BrkFace     Wd Shng       None         0.0         TA
# 9     CompShg     MetalSd     MetalSd       None         0.0         TA
# 10    CompShg     HdBoard     HdBoard       None         0.0         TA
# 11    CompShg     WdShing     Wd Shng      Stone       286.0         Ex
# 12    CompShg     HdBoard     Plywood       None         0.0         TA
# 13    CompShg     VinylSd     VinylSd      Stone       306.0         Gd
# 14    CompShg     MetalSd     MetalSd    BrkFace       212.0         TA
# 15    CompShg     Wd Sdng     Wd Sdng       None         0.0         TA
# 16    CompShg     Wd Sdng     Wd Sdng    BrkFace       180.0         TA
# 17    CompShg     MetalSd     MetalSd       None         0.0         TA
# 18    CompShg     VinylSd     VinylSd       None         0.0         TA
# 19    CompShg     BrkFace     Plywood       None         0.0         TA
# 20    CompShg     VinylSd     VinylSd    BrkFace       380.0         Gd
# 21    CompShg     Wd Sdng     Wd Sdng       None         0.0         TA
# 22    CompShg     VinylSd     VinylSd    BrkFace       281.0         Gd
# 23    CompShg     CemntBd     CmentBd       None         0.0         TA
# 24    CompShg     Plywood     Plywood       None         0.0         TA
# 25    CompShg     VinylSd     VinylSd      Stone       640.0         Gd
# 26    CompShg     Wd Sdng     Wd Sdng       None         0.0         TA
# 27    CompShg     VinylSd     VinylSd      Stone       200.0         Gd
# 28    CompShg     MetalSd     MetalSd       None         0.0         TA
# 29    CompShg     MetalSd     MetalSd       None         0.0         TA
# ...       ...         ...         ...        ...         ...        ...
# 1430  CompShg     VinylSd     VinylSd       None         0.0         Gd
# 1431  CompShg     Plywood     Plywood       None         0.0         TA
# 1432  CompShg     Wd Sdng     Wd Sdng       None         0.0         TA
# 1433  CompShg     VinylSd     VinylSd    BrkFace       318.0         TA
# 1434  CompShg     BrkFace     BrkFace       None         0.0         TA
# 1435  CompShg     Wd Sdng     Wd Sdng    BrkFace       237.0         Gd
# 1436  CompShg     HdBoard     HdBoard       None         0.0         TA
# 1437  CompShg     VinylSd     VinylSd      Stone       426.0         Ex
# 1438  CompShg     MetalSd     MetalSd       None         0.0         TA
# 1439  CompShg     HdBoard     HdBoard    BrkFace        96.0         TA
# 1440  CompShg     MetalSd     MetalSd       None         0.0         TA
# 1441  CompShg     VinylSd     VinylSd    BrkFace       147.0         Gd
# 1442  CompShg     VinylSd     VinylSd      Stone       160.0         Ex
# 1443  CompShg     Wd Sdng     Wd Sdng       None         0.0         TA
# 1444  CompShg     VinylSd     VinylSd    BrkFace       106.0         Gd
# 1445  CompShg     VinylSd     VinylSd       None         0.0         TA
# 1446  CompShg     HdBoard     HdBoard    BrkFace       189.0         TA
# 1447  CompShg     VinylSd     VinylSd    BrkFace       438.0         Gd
# 1448  CompShg     MetalSd     HdBoard       None         0.0         TA
# 1449  CompShg     CemntBd     CmentBd       None         0.0         TA
# 1450  CompShg     VinylSd     VinylSd       None         0.0         TA
# 1451  CompShg     CemntBd     CmentBd      Stone       194.0         Gd
# 1452  CompShg     VinylSd     VinylSd    BrkFace        80.0         TA
# 1453  CompShg     VinylSd     VinylSd       None         0.0         TA
# 1454  CompShg     VinylSd     VinylSd       None         0.0         Gd
# 1455  CompShg     VinylSd     VinylSd       None         0.0         TA
# 1456  CompShg     Plywood     Plywood      Stone       119.0         TA
# 1457  CompShg     CemntBd     CmentBd       None         0.0         Ex
# 1458  CompShg     MetalSd     MetalSd       None         0.0         TA
# 1459  CompShg     HdBoard     HdBoard       None         0.0         Gd
#
#       ExterCond
# 0            TA
# 1            TA
# 2            TA
# 3            TA
# 4            TA
# 5            TA
# 6            TA
# 7            TA
# 8            TA
# 9            TA
# 10           TA
# 11           TA
# 12           TA
# 13           TA
# 14           TA
# 15           TA
# 16           TA
# 17           TA
# 18           TA
# 19           TA
# 20           TA
# 21           TA
# 22           TA
# 23           TA
# 24           Gd
# 25           TA
# 26           TA
# 27           TA
# 28           TA
# 29           TA
# ...         ...
# 1430         TA
# 1431         TA
# 1432         TA
# 1433         TA
# 1434         TA
# 1435         Gd
# 1436         TA
# 1437         TA
# 1438         TA
# 1439         TA
# 1440         TA
# 1441         TA
# 1442         TA
# 1443         TA
# 1444         TA
# 1445         TA
# 1446         TA
# 1447         TA
# 1448         TA
# 1449         TA
# 1450         TA
# 1451         TA
# 1452         TA
# 1453         TA
# 1454         TA
# 1455         TA
# 1456         TA
# 1457         Gd
# 1458         TA
# 1459         TA
#
# [1460 rows x 29 columns]

# %%
df[df.columns[29:55]].columns
# Out:
# Index(['Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath',
#        'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd'],
#       dtype='object')
